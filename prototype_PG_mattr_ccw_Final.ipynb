# %% [markdown]
# <a href="https://colab.research.google.com/github/ms624atyale/PictureBook_Archive_inProgress/blob/main/prototype_PG_mattr_ccw_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **📕 Children's Picture Books**
#  - #### Project Gutenberg
# - #### 5 authors (Watty Piper, Beatrix Potter, Leslie Brooke, Walter Crane, Edward Lear)
#
# ### <font color = 'red'> **Original script for MK316's 📃 KSAT data process (as of 1005)**

# %% [markdown]
# ## Read data file from Github, Add string length, Number of splitted words (N_Splits)

# %% [markdown]
# original data from MK316: https://raw.githubusercontent.com/MK316/Workingpapers/main/Analysis/mydata01.csv (17 items)
#
# data used for analysis of Children's Picture Books as of 07OAPR25

# %% [markdown]
# ###🐹🐾 **1️⃣ Pandas Library**

# %%
import pandas as pd #Import Pandas Package

# %% [markdown]
# ###🐹🐾 **2️⃣ Clone a repository on your github**

# %%
# !git clone 'https://github.com/ms624atyale/PictureBook_Archive_inProgress'

# %% [markdown]
# ###🐹🐾 **3️⃣ Set your cuttent directory of your data folder where your txt file(s) are saved**
#
# - convert your txt file to matrix using DataFrame( ) class
# - set your current directory using %cd
# - save your data with DataFrame configure to csv(comma separated values)

# %%
# %cd /content/PictureBook_Archive_inProgress/Data_Final

import glob
fns = glob.glob('*.txt')
df = pd.DataFrame()
for fn in fns:
  dftmp = pd.read_csv(fn, sep="@")
  df = pd.concat([df, dftmp])

# %cd /content

df

print(df)

df.to_csv("./pg_all_txt_final.csv") #csv file saved in the  directory of Colab
# Out:
# /content/PictureBook_Archive_inProgress/Data_Final
# /content
#                                                 text  \
# 0  one morning a little rabbit sat on a bank.  he...
# 1  a farmyard tale     for     ralph and betsy   ...
# 2  once upon a time there was a little girl calle...
# 3  once upon a time there were four little rabbit...
# 4  this is a tale about a tail--a tail that belon...
# 5  once upon a time there were three little kitte...
# 0  there was once a sweet little maid who lived w...
# 0  “an alphabet of old friends a  a carrion crow ...
# 1  the baby's opera  1. girls and boys come out t...
# 2  “the baby’s own Aesop Aesop’s fables the fox &...
# 3  the old english garden  a floral phantasy     ...
# 0  a carrion crow sat on an oak,   fol de riddle,...
# 1  there was once a man who had three sons, the y...
# 2  johnny crow would dig and sow  till he made a ...
# 3  the man in the moon.             the man in th...
# ...

# %% [markdown]
# ###🐹🐾 **4️⃣ Locate integer index using iloc[[ ]], and specify row(s) by authors**

# %% [markdown]
#  4️⃣-1️⃣ BeatrixPotter

# %%
BeatrixPotter = df.iloc[[0,1,2,3,4,5]]
print(BeatrixPotter)
BeatrixPotter.to_csv("./BeatrixPotter.csv")
# Out:
#                                                 text  \
# 0  one morning a little rabbit sat on a bank.  he...
# 1  a farmyard tale     for     ralph and betsy   ...
# 2  once upon a time there was a little girl calle...
# 3  once upon a time there were four little rabbit...
# 4  this is a tale about a tail--a tail that belon...
# 5  once upon a time there were three little kitte...
#
#                                title           author
# 0         the tale of benjamin bunny   beatrix potter
# 1     the tale of jemima puddle-duck   beatrix potter
# 2      the tale of mrs. tiggy-winkle  beatrix potter
# 3  red riding hood and other stories   beatrix potter
# 4        the tale of squirrel nutkin  beatrix potter
# 5             the tale of tom kitten   beatrix potter

# %% [markdown]
#  4️⃣-2️⃣ Watty Piper

# %%
WattyPiper = df.iloc[[6]]
print(WattyPiper)
WattyPiper.to_csv("./WattyPiper.csv")
# Out:
#                                                 text  \
# 0  there was once a sweet little maid who lived w...
#
#                                       title        author
# 0  little red riding hood and other stories  watty piper

# %% [markdown]
#  4️⃣-3️⃣ Walter Crane

# %%
WalterCrane = df.iloc[[7,8,9,10]]
print(WalterCrane)
WalterCrane.to_csv("./WalterCrane.csv")
# Out:
#                                                 text  \
# 0  “an alphabet of old friends a  a carrion crow ...
# 1  the baby's opera  1. girls and boys come out t...
# 2  “the baby’s own Aesop Aesop’s fables the fox &...
# 3  the old english garden  a floral phantasy     ...
#
#                                        title         author
# 0                 an alphabet of old friends  walter crane
# 1                           the baby's opera  walter crane
# 2                   baby's own æsop's fables  walter crane
# 3  a floral fantasy in an old english garden  walter crane

# %% [markdown]
#  4️⃣-4️⃣ Leslie Brooke

# %%
LeslieBrooke = df.iloc[[11,12,13,14]]
print(LeslieBrooke)
LeslieBrooke.to_csv("./LeslieBrooke.csv")
# Out:
#                                                 text                    title  \
# 0  a carrion crow sat on an oak,   fol de riddle,...  the tailor and the crow
# 1  there was once a man who had three sons, the y...         the golden goose
# 2  johnny crow would dig and sow  till he made a ...     johnny crow's garden
# 3  the man in the moon.             the man in th...          a nursery rhyme
#
#            author
# 0   leslie brooke
# 1  leslie brooke
# 2   leslie brooke
# 3   leslie brooke

# %% [markdown]
#  4️⃣-5️⃣ Edward Lear

# %%
EdwardLear = df.iloc[[15]]
print(EdwardLear)
EdwardLear.to_csv("./EdwardLear.csv")
# Out:
#                                                 text            title  \
# 0  nonsense books how pleasant to know mr. lear! ...  nonsense books"
#
#          author
# 0  edward lear

# %% [markdown]
# ###🐹🐾 **5️⃣  Download each csv files under Colab Files by author**
# - Upload the csv files to your github Data_Final folder

# %% [markdown]
# ###🐹🐾 **6️⃣  Open your csv file with raw at raw.githubusercontent.com and copy & paste the url**

# %%
url = "https://raw.githubusercontent.com/ms624atyale/PictureBook_Archive_inProgress/refs/heads/main/Data_Final/pg_all_5authors_final.csv"

df1 = pd.read_csv(url)

# %%
# import chardet
# with open('/content/ksatdata_item17.csv', 'rb') as f:
#   enc = chardet.detect(f.read())
# df1 = pd.read_csv('/content/ksatdata_item17.csv', encoding=enc['encoding'])

# %%
df1
# Out:
#     Unnamed: 0                                               text  \
# 0            0  one morning a little rabbit sat on a bank.  he...
# 1            1  a farmyard tale     for     ralph and betsy   ...
# 2            2  once upon a time there was a little girl calle...
# 3            3  once upon a time there were four little rabbit...
# 4            4  this is a tale about a tail--a tail that belon...
# 5            5  once upon a time there were three little kitte...
# 6            0  there was once a sweet little maid who lived w...
# 7            0  “an alphabet of old friends a  a carrion crow ...
# 8            1  the baby's opera  1. girls and boys come out t...
# 9            2  “the baby’s own Aesop Aesop’s fables the fox &...
# 10           3  the old english garden  a floral phantasy     ...
# 11           0  a carrion crow sat on an oak,   fol de riddle,...
# 12           1  there was once a man who had three sons, the y...
# ...

# %% [markdown]
# # Adding a colum with length info

# %%
df2 = df1

# %%
# Added column: String length
length = []

for i in range(0, len(df2['text'])):
  LEN = len(df2['text'][i])
  length.append(LEN)

df2['Data size'] = length
df2
# Out:
#     Unnamed: 0                                               text  \
# 0            0  one morning a little rabbit sat on a bank.  he...
# 1            1  a farmyard tale     for     ralph and betsy   ...
# 2            2  once upon a time there was a little girl calle...
# 3            3  once upon a time there were four little rabbit...
# 4            4  this is a tale about a tail--a tail that belon...
# 5            5  once upon a time there were three little kitte...
# 6            0  there was once a sweet little maid who lived w...
# 7            0  “an alphabet of old friends a  a carrion crow ...
# 8            1  the baby's opera  1. girls and boys come out t...
# 9            2  “the baby’s own Aesop Aesop’s fables the fox &...
# 10           3  the old english garden  a floral phantasy     ...
# 11           0  a carrion crow sat on an oak,   fol de riddle,...
# 12           1  there was once a man who had three sons, the y...
# ...

# %%
# Added column:  Splitted words, Length of splitted words
tsplit = []
splen = []

for i in range(0, len(df2['text'])):
  TSP = df2['text'][i].split()
  SPLEN = len(TSP)
  tsplit.append(TSP)
  splen.append(SPLEN)
  # print(TSP)

df2['Splits'] = tsplit
df2['N_Splits'] = splen
df2
# Out:
#     Unnamed: 0                                               text  \
# 0            0  one morning a little rabbit sat on a bank.  he...
# 1            1  a farmyard tale     for     ralph and betsy   ...
# 2            2  once upon a time there was a little girl calle...
# 3            3  once upon a time there were four little rabbit...
# 4            4  this is a tale about a tail--a tail that belon...
# 5            5  once upon a time there were three little kitte...
# 6            0  there was once a sweet little maid who lived w...
# 7            0  “an alphabet of old friends a  a carrion crow ...
# 8            1  the baby's opera  1. girls and boys come out t...
# 9            2  “the baby’s own Aesop Aesop’s fables the fox &...
# 10           3  the old english garden  a floral phantasy     ...
# 11           0  a carrion crow sat on an oak,   fol de riddle,...
# 12           1  there was once a man who had three sons, the y...
# ...

# %%
df2.describe()
# Out:
#        Unnamed: 0      Data size      N_Splits
# count   16.000000      16.000000     16.000000
# mean     1.687500   19053.375000   3195.875000
# std      1.579821   43548.565519   6882.913132
# min      0.000000     854.000000    153.000000
# 25%      0.000000    3993.500000    679.000000
# 50%      1.500000    6570.000000   1165.000000
# 75%      3.000000   14340.250000   2692.500000
# max      5.000000  180413.000000  28542.000000

# %% [markdown]
# # Lexical Diversity Indices (6 types)

# %% [markdown]
# ## Getting LD indices

# %%
# !pip install lexical-diversity
from lexical_diversity import lex_div as ld

# %%
# Added column: String length
lem = []

for i in range(0, len(df2['text'])):
  LEM = ld.flemmatize(df2['text'][i])
  print(LEM)
  lem.append(LEM)

df2['Lemma'] = lem
# Out:
# ['one', 'morning', 'a', 'little', 'rabbit', 'sit', 'on', 'a', 'bank', 'he', 'prick', 'his', 'ear', 'and', 'listen', 'to', 'the', 'trittrot', 'trittrot', 'of', 'a', 'pony', 'a', 'gig', 'be', 'coming', 'along', 'the', 'road', 'it', 'be', 'drive', 'by', 'mr', 'mcgregor', 'and', 'beside', 'him', 'sit', 'mrs', 'mcgregor', 'in', 'her', 'best', 'bonnet', 'as', 'soon', 'as', 'they', 'have', 'pass', 'little', 'benjamin', 'bunny', 'slide', 'down', 'into', 'the', 'road', 'and', 'set', 'offwith', 'a', 'hop', 'skip', 'and', 'a', 'jumpto', 'call', 'upon', 'his', 'relation', 'who', 'live', 'in', 'the', 'wood', 'at', 'the', 'back', 'of', 'mr', 'mcgregors', 'garden', 'that', 'wood', 'be', 'full', 'of', 'rabbit', 'hole', 'and', 'in', 'the', 'neat', 'sandy', 'hole', 'of', 'all', 'live', 'benjamins', 'aunt', 'and', 'his', 'cousinsflopsy', 'mopsy', 'cottontail', 'and', 'peter', 'old', 'mrs', 'rabbit', 'be', 'a', 'widow', 'she', 'earn', 'her', 'living', 'by', 'knit', 'rabbitwool', 'mitten', 'and', 'muffat
# ...

# %%
# ADD LD indices

#1. Create empty lists.
TTR = []
RTTR = []
LogTTR = []
MassTTR = []
MSTTR = []
MATTR = []


# 2. Getting LD index values for each cell:

for i in range(0, len(df2['Lemma'])):
  flt = df2['Lemma'][i]
  ttr = ld.ttr(flt)
  rttr = ld.root_ttr(flt)
  logttr = ld.log_ttr(flt)
  mass = ld.maas_ttr(flt)
  msttr = ld.msttr(flt)
  mattr = ld.mattr(flt)


  # Add values to each list
  TTR.append(ttr)
  RTTR.append(rttr)
  LogTTR.append(logttr)
  MassTTR.append(mass)
  MSTTR.append(msttr)
  MATTR.append(mattr)


# Add columns
df2['TTR'] = TTR
df2['RTTR'] = RTTR
df2['LogTTR'] = LogTTR
df2['MassTTR'] = MassTTR
df2['MSTTR'] = MSTTR
df2['MATTR'] = MATTR

# %% [markdown]
# N of sentences

# %%
# !pip install textstat
import textstat

# %% [markdown]
# Result file: N of sentences included

# %%
df2['N_Sents'] = df2['text'].apply(textstat.sentence_count)
df2.to_csv('LD_result_with_Nsents.csv')

# %% [markdown]
# ## Result file

# %%
df2.describe()
# Out:
#        Unnamed: 0    Data size     N_Splits       TTR       RTTR    LogTTR  \
# count    6.000000     6.000000     6.000000  6.000000   6.000000  6.000000
# mean     2.500000  6138.500000  1082.166667  0.345207  11.235162  0.847119
# std      1.870829  1357.856509   225.007926  0.023996   0.747918  0.005952
# min      0.000000  3917.000000   691.000000  0.322351  10.081075  0.838816
# 25%      1.250000  5452.250000   991.750000  0.327274  10.903041  0.842850
# 50%      2.500000  6570.000000  1165.000000  0.338760  11.229750  0.848403
# 75%      3.750000  7003.000000  1240.750000  0.358007  11.835027  0.851611
# max      5.000000  7547.000000  1272.000000  0.383502  12.039472  0.853412
#
#         MassTTR     MSTTR     MATTR    N_Sents
# count  6.000000  6.000000  6.000000   6.000000
# mean   0.050554  0.780164  0.783324  72.833333
# std    0.001672  0.012456  0.010195  15.289430
# min    0.048795  0.764615  0.769969  51.000000
# 25%    0.049117  0.771193  0.776770  63.500000
# ...

# %% [markdown]
# # Plotting

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
sns.set(rc={'figure.figsize':(8,6),"font.size":40,"axes.titlesize":140,"axes.labelsize":60},style="white") # font size doesn't work
# ax = sns.boxplot (y=df2)
# ax.set_ylim([0, 90000])

sns.set_theme(style='white')
dd=pd.melt(df2,id_vars=['author'],value_vars=['N_Splits'],var_name='Tokens') #🆘 Oiginal id_vars=['author'] from previous version
ax = sns.boxplot(x='author',y='value',data=dd,hue='Tokens',palette="Accent") #🆘 Oiginal x ='author' from previous version
ax.set_ylim([0,9000])
ax.set(xlabel='author', ylabel='N of words (count)') #🆘 Oiginal x ='author' from previous version
plt.savefig('boxplot_Nsplit.png')

# %%
sns.kdeplot(x='N_Splits', data=df2, hue='author', common_norm=False); #🆘 Oiginal hue = 'author' from previous version
plt.title("Kernel Density Function")
plt.savefig('Density_Nsplit.png')
# Out:
# <ipython-input-69-664f5d4ec4a0>:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(x='N_Splits', data=df2, hue='author', common_norm=False); #🆘 Oiginal hue = 'author' from previous version

# %%
sns.scatterplot(data=df2, x="author", y="N_Splits") #🆘 Oiginal x = 'author' from previous version
sns.rugplot(data=df2, x="author", y="N_Splits", height=.1) #🆘 Oiginal x = 'author' from previous version
plt.savefig('Rug_Nsplit.png')

# %% [markdown]
# 문항별 어휘수 및 문장수

# %%
sns.set(rc={'figure.figsize':(12,6),"font.size":40,"axes.titlesize":20,"axes.labelsize":20},style="white") # font size doesn't work
sns.scatterplot(data=df2, x="author", y="N_Splits") #🆘 Oiginal x = 'author' from previous version
ax = sns.rugplot(data=df2, x="author", y="N_Splits", height=.1) #🆘 Oiginal x = 'author' from previous version
ax.set_ylim([0,6000])
ax.set(xlabel='author', ylabel='N of words (count)')
plt.savefig('Rug_Nsplit_byYearPublished.png')

# %% [markdown]
# # Lexical Diversity analysis: select TTR, MassTTR, MTLD, HDD

# %%
df3 = df2
for col in df3.columns:
    print(col)
# Out:
# Unnamed: 0
# text
# title
# author
# Data size
# Splits
# N_Splits
# Lemma
# TTR
# RTTR
# LogTTR
# MassTTR
# MSTTR
# MATTR
# N_Sents

# %%
df3 = df2[['author','N_Splits','N_Sents','TTR','MATTR']]
df3.head(10)
# Out:
#             author  N_Splits  N_Sents       TTR     MATTR
# 0   beatrix potter      1123       78  0.322351  0.775307
# 1   beatrix potter      1252       90  0.340256  0.789842
# 2  beatrix potter       1272       88  0.337264  0.785315
# 3   beatrix potter       948       62  0.363924  0.798354
# 4  beatrix potter       1207       68  0.323944  0.781157
# 5   beatrix potter       691       51  0.383502  0.769969
# 6     watty piper       2654      135  0.223060  0.742587
# 7    walter crane        925       60  0.434595  0.718265
# 8    walter crane       3066      211  0.236791  0.667299
# 9    walter crane       2808      122  0.318732  0.771105

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string
from collections import Counter

# Download necessary NLTK resources
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')

# Load the dataset
file_path = "picture_books.csv"  # Change to your actual file name
df = pd.read_csv('/content/pg_all_txt_final.csv')

# Ensure the text column exists
if 'text' not in df.columns or 'author' not in df.columns:
    raise ValueError("CSV file must contain 'text' and 'author' columns.")

# Combine all text data into one large string
all_text = " ".join(df['text'].astype(str))

# Tokenize words
words = word_tokenize(all_text.lower())  # Convert to lowercase

# Remove punctuation and stopwords
stop_words = set(stopwords.words('english'))
words = [word for word in words if word.isalpha() and word not in stop_words]  # Keep only words, no numbers/symbols

# Count word frequencies
word_counts = Counter(words)

# Convert to a DataFrame
common_words_df = pd.DataFrame(word_counts.most_common(100), columns=['Word', 'Frequency'])  # Top 100 words

# Save to CSV
common_words_df.to_csv("5authors_common_core_words.csv", index=False)

print("Common core words extracted and saved as '5authors_common_core_words.csv'!")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Common core words extracted and saved as '5authors_common_core_words.csv'!

# %% [markdown]
# # **<font color = 'red'> Common Core Words<font/>** (Idea from 정채관 2022)

# %%
url = "https://raw.githubusercontent.com/ms624atyale/PictureBook_Archive_inProgress/refs/heads/main/Input_Data/PG_ChildrenPictureBooks_7Authors.csv"

df = pd.read_csv(url)

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string
from collections import Counter

# Download necessary NLTK resources
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')

# Load the dataset
file_path = "https://raw.githubusercontent.com/ms624atyale/PictureBook_Archive_inProgress/refs/heads/main/Input_Data/PG_ChildrenPictureBooks_7Authors.csv"  # Change to your actual file name
df = pd.read_csv(file_path)

# Ensure the CSV file has the necessary columns
if 'text' not in df.columns or 'author' not in df.columns:
    raise ValueError("CSV file must contain 'text' and 'author' columns.")

# Combine all text data into one large string
all_text = " ".join(df['text'].astype(str))

# Tokenize words
words = word_tokenize(all_text.lower())  # Convert to lowercase

# Remove punctuation and stopwords
stop_words = set(stopwords.words('english'))
words = [word for word in words if word.isalpha() and word not in stop_words]  # Keep only words (no numbers/symbols)

# Count word frequencies
word_counts = Counter(words)

# Convert to a DataFrame
common_words_df = pd.DataFrame(word_counts.most_common(500), columns=['Word', 'Frequency'])  # Top 500 CCW

# Save to CSV
common_words_df.to_csv("common_core_words.csv", index=False)

print("✅ Common Core Words extracted and saved as 'common_core_words.csv'!")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ✅ Common Core Words extracted and saved as 'common_core_words.csv'!

# %% [markdown]
# #🚫 🚫 🚫 Irrelevant to Children's Picture Books. Ignore Below ⤵️
